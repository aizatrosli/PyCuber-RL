# %%
import numpy as np
import os,sys

ROOT_DIR = os.path.abspath("../")
sys.path.append(ROOT_DIR)

from core.rlCuber import *

# %%
env = rlcuber()
print(env.observation_spacen())
print(env.action_spacen())
# Out:
# 54
# 6

# %%
#Initialize table with all zeros
Q = np.zeros([env.observation_spacen(),env.action_spacen()])
# Set learning parameters
lr = .8
y = .95
num_episodes = 2000
#create lists to contain total rewards and steps per episode
#jList = []
rList = []
for i in range(num_episodes):
    #Reset environment and get first new observation
    s = env.reset()
    print("===== new episode =====")
    rAll = 0
    d = False
    j = 0
    shigh = 0
    #The Q-Table learning algorithm
    while j < 99:
        j+=1
        #Choose an action by greedily (with noise) picking from Q table
        noise = Q[s,:] + np.random.randn(1,env.action_spacen())*(1./(i+1))
        a = np.argmax(noise)
        #Get new state and reward from environment
        s1,r,d = env.step(a)
        #Update Q-Table with new knowledge
        Q[s,a] = Q[s,a] + lr*(r + y*np.max(Q[s1,:]) - Q[s,a])
        rAll += r
        s = s1
        if s>shigh:
            shigh = s
        if d == True:
            break
    #jList.append(j)
    rList.append(rAll)
# Out:
# 0
# [[ 0.43621069 -1.24967464 -0.41458456 -1.29093009  0.40302379  0.38558835]]
#          [g][g][r]
#          [w][y][w]
#          [b][b][w]
# [w][o][w][r][o][o][g][b][g][y][w][r]
# [o][r][g][r][g][r][y][o][b][r][b][g]
# [g][b][b][y][o][y][b][g][b][w][r][o]
#          [r][y][o]
#          [y][w][y]
#          [y][w][o]
#
# [[-0.45913556  0.21043213  0.90554362  1.3204153  -0.61789284  0.85715304]]
#          [g][g][r]
#          [w][y][w]
#          [b][g][w]
# [w][o][r][y][r][r][b][b][g][y][w][r]
# [o][r][y][o][g][o][b][o][b][r][b][g]
# [g][b][o][y][r][o][w][g][b][w][r][o]
#          [b][y][g]
#          [y][w][y]
#          [y][w][o]
#
# [[-2.17137107 -1.00528624 -1.19716366  1.15159839  0.4623951  -0.72561315]]
#          [g][g][r]
#          [w][y][w]
#          [o][y][r]
# [w][o][b][y][o][y][b][b][g][y][w][r]
# [o][r][y][r][g][r][g][o][b][r][b][g]
# [g][b][g][o][o][r][w][g][b][w][r][o]
#          [w][b][b]
#          [y][w][y]
#          [y][w][o]
#
# [[-0.33036953  0.81611734 -0.57985338 -0.32475499 -0.59130351  0.44814816]]
#          [o][w][g]
#          [y][y][g]
#          [r][w][r]
# [y][o][y][b][b][g][y][w][r][w][o][b]
# [o][r][y][r][g][r][g][o][b][r][b][g]
# [g][b][g][o][o][r][w][g][b][w][r][o]
#          [w][b][b]
#          [y][w][y]
#          [y][w][o]
#
# [[-0.26932147 -0.39699676 -0.4288923  -0.04787493 -1.82069724 -1.02740631]]
#          [o][w][g]
#          [y][y][g]
#          [g][y][y]
# [y][o][w][o][r][b][r][w][r][w][o][b]
# [o][r][b][o][g][b][w][o][b][r][b][g]
# [g][b][b][r][r][g][r][g][b][w][r][o]
#          [w][g][y]
#          [y][w][y]
#          [y][w][o]
#
# [[ 0.50785472 -1.13328536  1.09831252 -0.89380612 -1.63456983  1.59442074]]
#          [o][w][g]
#          [g][y][g]
#          [b][y][y]
# [g][o][y][o][r][b][r][w][r][w][o][y]
# [b][r][o][y][g][b][w][o][b][r][b][y]
# [b][b][w][g][r][g][r][g][b][w][r][w]
#          [o][g][y]
#          [o][w][y]
#          [r][w][o]
#
# [[-0.18521574 -0.46967935  0.20254585  0.77973455  0.23514902 -1.64258085]]
#          [o][w][g]
#          [g][y][g]
#          [w][o][y]
# [g][o][o][g][y][o][b][w][r][w][o][y]
# [b][r][g][r][g][r][y][o][b][r][b][y]
# [b][b][y][g][b][b][y][g][b][w][r][w]
#          [r][w][r]
#          [o][w][y]
#          [r][w][o]
#
# [[ 0.18562982 -0.03768229  0.34286225 -0.1334723   0.03652005  1.13840805]]
#          [w][w][g]
#          [y][y][g]
#          [y][o][y]
# [b][b][g][o][y][o][b][w][r][w][o][r]
# [b][r][o][g][g][r][y][o][b][r][b][o]
# [y][g][o][w][b][b][y][g][b][w][r][r]
#          [g][w][r]
#          [r][w][y]
#          [g][w][o]
#
# [[ 0.07031677 -0.83140316 -1.34464572 -0.98867412 -0.07114894 -0.73580314]]
#          [r][b][b]
#          [y][y][g]
#          [y][o][y]
# [g][b][g][o][y][o][b][w][o][w][r][w]
# [w][r][o][g][g][r][y][o][w][r][b][o]
# [w][g][o][w][b][b][y][g][g][r][o][r]
#          [g][w][r]
#          [r][w][y]
#          [b][b][y]
#
# [[ 0.98330883 -0.43983546  0.22442046  0.43117692 -0.47538834  0.85485615]]
#          [o][w][g]
#          [y][y][g]
#          [y][o][y]
# [b][b][g][o][y][o][b][w][y][r][r][w]
# [b][r][o][g][g][r][y][o][b][o][b][r]
# [r][g][o][w][b][b][y][g][b][r][o][w]
#          [g][w][r]
#          [r][w][y]
#          [g][w][w]
#
# [[-2.14233449 -0.06459739  0.71534162  0.21748472  0.0411406  -0.551253  ]]
#          [o][w][o]
#          [y][y][r]
#          [y][o][b]
# [b][b][g][o][y][r][y][y][b][y][r][w]
# [b][r][o][g][g][y][g][o][w][g][b][r]
# [r][g][o][w][b][w][b][b][y][g][o][w]
#          [g][w][r]
#          [r][w][o]
#          [g][w][r]
#
# [[-1.47796399 -0.8237368   0.10542449  1.53310668  0.89700975 -0.62353283]]
#          [o][w][o]
#          [y][y][r]
#          [o][o][g]
# [b][b][g][w][g][o][y][y][b][y][r][w]
# [b][r][w][b][g][y][o][o][w][g][b][r]
# [r][g][r][w][y][r][b][b][y][g][o][w]
#          [b][g][y]
#          [r][w][o]
#          [g][w][r]
#
# [[ 1.31568819  0.4978637  -1.63431257 -0.84942507 -1.27125973 -2.00805786]]
#          [b][w][y]
#          [y][y][r]
#          [o][o][g]
# [o][b][g][w][g][o][y][y][r][g][g][y]
# [w][r][w][b][g][y][o][o][w][o][b][r]
# [o][g][r][w][y][r][b][b][g][w][r][w]
#          [b][g][y]
#          [r][w][o]
#          [b][b][r]
#
# [[-0.02616447  1.12627646  0.99332718 -0.95291852 -1.1409897   0.83509354]]
#          [o][y][b]
#          [o][y][w]
#          [g][r][y]
# [w][g][o][y][y][r][g][g][y][o][b][g]
# [w][r][w][b][g][y][o][o][w][o][b][r]
# [o][g][r][w][y][r][b][b][g][w][r][w]
#          [b][g][y]
#          [r][w][o]
#          [b][b][r]
#
# [[-0.48070073 -0.84476169 -1.32167653 -0.01508685 -0.54146736  1.18163307]]
#          [w][y][b]
#          [r][y][w]
#          [g][r][y]
# [o][w][w][o][y][r][g][g][y][o][b][b]
# [g][r][g][o][g][y][o][o][w][o][b][r]
# [r][w][o][g][y][r][b][b][g][w][r][b]
#          [y][g][y]
#          [b][w][o]
#          [w][b][r]
#
# [[-0.1605164  -1.51792534  0.19546696 -0.03683417  0.5460065   1.63816307]]
#          [b][y][b]
#          [r][y][w]
#          [b][r][y]
# [r][g][o][w][y][r][g][g][y][o][b][w]
# [w][r][w][r][g][y][o][o][w][o][b][b]
# [o][g][w][g][y][r][b][b][g][w][r][y]
#          [o][g][y]
#          [o][w][o]
#          [g][b][r]
#
# [[ 2.4569957  -0.00946068  1.49391242  0.52866606  0.59938481  0.40578953]]
#          [y][w][g]
#          [r][y][w]
#          [b][r][y]
# [b][g][o][w][y][r][g][g][r][w][o][o]
# [y][r][w][r][g][y][o][o][b][r][b][b]
# [b][g][w][g][y][r][b][b][g][y][b][w]
#          [o][g][y]
#          [o][w][o]
#          [r][w][o]
#
# [[-0.53575196 -1.82347035 -0.89332927 -0.91922434 -0.87299731  2.08097914]]
#          [w][w][g]
#          [b][y][w]
#          [o][r][y]
# [b][y][b][y][y][r][g][g][r][w][o][r]
# [g][r][g][r][g][y][o][o][b][r][b][o]
# [w][w][o][b][y][r][b][b][g][y][b][o]
#          [w][g][y]
#          [r][w][o]
#          [g][w][o]
#
# [[-1.61593512 -1.62661953  0.59564147  1.43560748  0.20763655 -0.0293995 ]]
#          [w][w][g]
#          [b][y][w]
#          [o][g][b]
# [b][y][w][b][r][y][o][g][r][w][o][r]
# [g][r][g][y][g][y][r][o][b][r][b][o]
# [w][w][y][r][y][r][y][b][g][y][b][o]
#          [b][o][g]
#          [r][w][o]
#          [g][w][o]
#
# [[-0.61560055 -0.93720874 -0.65238161  1.20904914 -0.69957871  1.93314961]]
#          [o][w][g]
#          [o][y][w]
#          [r][g][b]
# [w][g][b][w][r][y][o][g][r][w][o][g]
# [w][r][y][b][g][y][r][o][b][r][b][r]
# [y][g][w][o][y][r][y][b][g][y][b][b]
#          [b][o][g]
#          [y][w][o]
#          [r][w][o]
#
# [[-1.96432157 -0.12282749 -1.15405328 -0.69320629 -0.46897689  0.27764074]]
#          [b][w][g]
#          [r][y][w]
#          [g][g][b]
# [y][w][w][o][r][y][o][g][r][w][o][r]
# [g][r][g][o][g][y][r][o][b][r][b][y]
# [w][y][b][r][y][r][y][b][g][y][b][b]
#          [w][o][g]
#          [b][w][o]
#          [o][w][o]
#
# [[-0.31593395  0.59407767  1.13184132  2.11604991  0.08035038 -1.63729441]]
#          [b][w][g]
#          [r][y][w]
#          [b][g][w]
# [y][w][w][r][o][o][g][g][r][w][o][r]
# [g][r][o][y][g][r][g][o][b][r][b][y]
# [w][y][g][r][y][y][b][b][g][y][b][b]
#          [y][r][o]
#          [b][w][o]
#          [o][w][o]
#
# [[ 0.15289396 -0.68663746 -0.99029281 -0.40718699  0.58604607 -0.98366706]]
#          [b][w][g]
#          [r][y][w]
#          [b][g][w]
# [y][w][w][r][o][o][g][g][r][w][o][r]
# [g][r][o][y][g][r][g][o][b][r][b][y]
# [y][b][b][w][y][g][r][y][y][b][b][g]
#          [o][b][y]
#          [w][w][r]
#          [o][o][o]
#
# [[ 0.86470131  1.31379373 -0.90264242 -0.10219873 -0.370954    0.26628367]]
#          [b][r][b]
#          [g][y][w]
#          [w][w][g]
# [r][o][o][g][g][r][w][o][r][y][w][w]
# [g][r][o][y][g][r][g][o][b][r][b][y]
# [y][b][b][w][y][g][r][y][y][b][b][g]
#          [o][b][y]
#          [w][w][r]
#          [o][o][o]
#
# [[-1.01512474  1.013015    0.34012753  0.18232037  0.1643292   0.67160747]]
#          [w][g][b]
#          [w][y][r]
#          [g][w][b]
# [g][g][r][w][o][r][y][w][w][r][o][o]
# [g][r][o][y][g][r][g][o][b][r][b][y]
# [y][b][b][w][y][g][r][y][y][b][b][g]
#          [o][b][y]
#          [w][w][r]
#          [o][o][o]
#
# [[ 0.29682235 -1.89372167  0.75659265 -0.45125724  0.17991669  0.18882489]]
#          [w][g][r]
#          [w][y][r]
#          [g][w][g]
# [g][g][r][w][o][y][r][g][y][b][o][o]
# [g][r][o][y][g][r][y][o][w][r][b][y]
# [y][b][b][w][y][o][y][b][w][b][b][g]
#          [o][b][b]
#          [w][w][r]
#          [o][o][r]
#
# [[-0.33129847 -0.18764514 -0.07257238 -0.33451409  1.35327306  1.12135674]]
#          [w][g][r]
#          [w][y][r]
#          [g][w][g]
# [g][g][r][w][o][y][r][g][y][b][o][o]
# [g][r][o][y][g][r][y][o][w][r][b][y]
# [b][b][g][y][b][b][w][y][o][y][b][w]
#          [o][w][o]
#          [o][w][b]
#          [r][r][b]
#
# [[-1.38250619 -2.12351595 -0.30624002 -1.03234531  1.85480515 -2.11963668]]
#          [w][g][r]
#          [w][y][r]
#          [g][w][g]
# [g][g][r][w][o][y][r][g][y][b][o][o]
# [g][r][o][y][g][r][y][o][w][r][b][y]
# [y][b][w][b][b][g][y][b][b][w][y][o]
#          [r][o][o]
#          [r][w][w]
#          [b][b][o]
#
# [[ 2.28099091  0.94166727 -1.32912231  0.66825964  1.04642004  0.51090012]]
#          [y][w][b]
#          [w][y][r]
#          [g][w][g]
# [r][g][r][w][o][y][r][g][o][w][r][b]
# [g][r][o][y][g][r][y][o][b][y][b][o]
# [w][b][w][b][b][g][y][b][b][o][y][o]
#          [r][o][o]
#          [r][w][w]
#          [g][g][y]
#
# [[ 1.47799262 -1.22976062 -0.08981808 -0.03320465  1.08002599 -0.451455  ]]
#          [o][b][b]
#          [w][y][r]
#          [g][w][g]
# [b][g][r][w][o][y][r][g][y][o][y][w]
# [w][r][o][y][g][r][y][o][g][y][b][r]
# [y][b][w][b][b][g][y][b][g][o][o][b]
#          [r][o][o]
#          [r][w][w]
#          [r][g][w]
#
# [[ 1.39785998 -0.34440379 -1.11783895 -0.79407332  0.58425341 -1.09209975]]
#          [y][g][g]
#          [w][y][r]
#          [g][w][g]
# [b][g][r][w][o][y][r][g][w][o][y][o]
# [b][r][o][y][g][r][y][o][g][o][b][y]
# [o][b][w][b][b][g][y][b][r][b][r][w]
#          [r][o][o]
#          [r][w][w]
#          [b][w][y]
#
# [[-0.52516268  1.75694754 -0.76337376  0.03968388 -0.26729484  0.2503669 ]]
#          [g][w][y]
#          [w][y][g]
#          [g][r][g]
# [w][o][y][r][g][w][o][y][o][b][g][r]
# [b][r][o][y][g][r][y][o][g][o][b][y]
# [o][b][w][b][b][g][y][b][r][b][r][w]
#          [r][o][o]
#          [r][w][w]
#          [b][w][y]
#
# [[-0.21062102  0.0823501  -1.2465536  -0.80728935  0.11362988 -0.80104643]]
#          [g][w][y]
#          [w][y][g]
#          [g][r][g]
# [w][o][y][r][g][w][o][y][o][b][g][r]
# [b][r][o][y][g][r][y][o][g][o][b][y]
# [b][r][w][o][b][w][b][b][g][y][b][r]
#          [b][r][r]
#          [w][w][o]
#          [y][w][o]
#
# [[ 0.06159867 -1.46059739 -0.57939814  0.18063058  0.3208741  -0.35232603]]
#          [g][w][y]
#          [w][y][g]
#          [g][r][g]
# [w][o][y][r][g][w][o][y][o][b][g][r]
# [b][r][o][y][g][r][y][o][g][o][b][y]
# [y][b][r][b][r][w][o][b][w][b][b][g]
#          [y][w][b]
#          [w][w][r]
#          [o][o][r]
#
# [[-1.25461316 -1.59904007 -0.50681348 -1.05502181  2.79296266 -0.9880831 ]]
#          [g][w][y]
#          [w][y][g]
#          [g][r][g]
# [w][o][y][r][g][w][o][y][o][b][g][r]
# [b][r][o][y][g][r][y][o][g][o][b][y]
# [b][b][g][y][b][r][b][r][w][o][b][w]
#          [o][w][y]
#          [o][w][w]
#          [r][r][b]
#
# [[-0.97121114  0.08885607 -1.63913064  0.30562126 -1.18373695 -0.84900353]]
#          [g][w][y]
#          [w][y][g]
#          [g][o][y]
# [w][o][o][y][y][r][g][y][o][b][g][r]
# [b][r][w][b][g][g][r][o][g][o][b][y]
# [b][b][y][r][r][w][g][r][w][o][b][w]
#          [b][y][o]
#          [o][w][w]
#          [r][r][b]
#
# [[-0.90797537  0.36692174 -0.06026052  0.41857463 -1.7736825   1.43097368]]
#          [w][w][y]
#          [y][y][g]
#          [r][o][y]
# [b][b][w][g][y][r][g][y][o][b][g][r]
# [b][r][o][w][g][g][r][o][g][o][b][o]
# [y][w][o][g][r][w][g][r][w][o][b][b]
#          [y][y][o]
#          [b][w][w]
#          [r][r][b]
#
# [[-0.63772668  0.97674549 -0.11724227 -1.61746614 -0.88673842  0.00610257]]
#          [r][y][w]
#          [o][y][w]
#          [y][g][y]
# [g][y][r][g][y][o][b][g][r][b][b][w]
# [b][r][o][w][g][g][r][o][g][o][b][o]
# [y][w][o][g][r][w][g][r][w][o][b][b]
#          [y][y][o]
#          [b][w][w]
#          [r][r][b]
#
# [[-0.24872315 -0.50630019  0.00801614 -1.59897266  0.63097774 -0.62821163]]
#          [r][y][w]
#          [o][y][w]
#          [y][g][y]
# [g][y][r][g][y][o][b][g][r][b][b][w]
# [b][r][o][w][g][g][r][o][g][o][b][o]
# [o][b][b][y][w][o][g][r][w][g][r][w]
#          [r][b][y]
#          [r][w][y]
#          [b][w][o]
#
# [[ 0.16035826  0.15022339 -1.41514696  0.12551839  0.38988619 -0.12990174]]
#          [r][y][w]
#          [o][y][w]
#          [y][g][y]
# [g][y][r][g][y][o][b][g][r][b][b][w]
# [b][r][o][w][g][g][r][o][g][o][b][o]
# [g][r][w][o][b][b][y][w][o][g][r][w]
#          [b][r][r]
#          [w][w][b]
#          [o][y][y]
#
# [[-0.15330072 -1.57870891  0.26554145 -1.55951192  0.21045323  1.17758809]]
#          [w][y][w]
#          [o][y][w]
#          [w][g][y]
# [g][b][g][r][y][o][b][g][r][b][b][o]
# [r][r][y][o][g][g][r][o][g][o][b][w]
# [w][o][r][y][b][b][y][w][o][g][r][b]
#          [g][r][r]
#          [w][w][b]
#          [o][y][y]
# [[ 0.50400323  0.37975601 -0.53240209  1.26507809 -1.68930284  0.35972982]]
#          [w][y][w]
#          [o][y][w]
#          [r][y][g]
# [g][b][g][y][o][r][w][g][r][b][b][o]
# [r][r][r][b][g][y][g][o][g][o][b][w]
# [w][o][r][b][g][o][y][w][o][g][r][b]
#          [y][r][b]
#          [w][w][b]
#          [o][y][y]
#
# [[-0.58409123 -0.56444483 -0.81542587 -0.67113661 -1.16866803  1.23138126]]
#          [b][y][w]
#          [w][y][w]
#          [o][y][g]
# [w][r][g][w][o][r][w][g][r][b][b][o]
# [o][r][b][o][g][y][g][o][g][o][b][w]
# [r][r][g][r][g][o][y][w][o][g][r][y]
#          [y][r][b]
#          [b][w][b]
#          [b][y][y]
#
# [[ 0.43931696 -0.33813466 -0.56796644  1.18900331  0.38247823  1.9431413 ]]
#          [y][y][w]
#          [w][y][w]
#          [o][y][g]
# [r][o][w][b][o][r][w][g][r][b][b][b]
# [r][r][r][w][g][y][g][o][g][o][b][b]
# [g][b][g][o][g][o][y][w][o][g][r][y]
#          [w][r][b]
#          [o][w][b]
#          [r][y][y]
#
# [[ 1.04041249  0.77400106 -0.51405458 -1.41493697  0.79847057 -0.79772577]]
#          [r][g][o]
#          [w][y][w]
#          [o][y][g]
# [w][o][w][b][o][r][w][g][y][g][o][b]
# [y][r][r][w][g][y][g][o][y][r][b][b]
# [y][b][g][o][g][o][y][w][r][y][b][b]
#          [w][r][b]
#          [o][w][b]
#          [r][r][g]
#
# [[ 1.26318812  1.43313446  1.31448183  1.58194    -0.56916986 -0.06679491]]
#          [r][g][o]
#          [w][y][w]
#          [g][r][w]
# [w][o][w][o][w][b][o][g][y][g][o][b]
# [y][r][r][g][g][o][y][o][y][r][b][b]
# [y][b][b][o][y][r][g][w][r][y][b][b]
#          [y][g][w]
#          [o][w][b]
#          [r][r][g]
#
# [[ 0.66950216  0.67821674 -0.2171333  -1.36692864 -0.92656711  0.08430627]]
#          [g][w][r]
#          [r][y][g]
#          [w][w][o]
# [o][w][b][o][g][y][g][o][b][w][o][w]
# [y][r][r][g][g][o][y][o][y][r][b][b]
# [y][b][b][o][y][r][g][w][r][y][b][b]
#          [y][g][w]
#          [o][w][b]
#          [r][r][g]
#
# [[ 0.40697887  0.94285847  0.56276865 -0.1652287  -2.00187818 -1.21687977]]
#          [w][r][g]
#          [w][y][w]
#          [o][g][r]
# [o][g][y][g][o][b][w][o][w][o][w][b]
# [y][r][r][g][g][o][y][o][y][r][b][b]
# [y][b][b][o][y][r][g][w][r][y][b][b]
#          [y][g][w]
#          [o][w][b]
#          [r][r][g]
#
# [[-1.25904504  0.69538267  0.09143543 -0.55992049 -0.71747736 -0.87122104]]
#          [o][w][w]
#          [g][y][r]
#          [r][w][g]
# [g][o][b][w][o][w][o][w][b][o][g][y]
# [y][r][r][g][g][o][y][o][y][r][b][b]
# [y][b][b][o][y][r][g][w][r][y][b][b]
#          [y][g][w]
#          [o][w][b]
#          [r][r][g]
#
# [[ 0.66490687 -1.31623844 -0.75595548  0.50633131  0.2628246  -2.37367332]]
#          [b][y][r]
#          [g][y][r]
#          [r][w][g]
# [w][o][b][w][o][w][o][w][g][y][r][o]
# [w][r][r][g][g][o][y][o][r][b][b][g]
# [o][b][b][o][y][r][g][w][r][b][b][y]
#          [y][g][w]
#          [o][w][b]
#          [g][y][y]
#
# [[ 1.19228196 -1.2759761  -0.36778229 -0.44608509  0.70094502  0.40915009]]
#          [g][r][r]
#          [g][y][r]
#          [r][w][g]
# [r][o][b][w][o][w][o][w][y][b][b][y]
# [y][r][r][g][g][o][y][o][y][b][b][r]
# [b][b][b][o][y][r][g][w][g][y][g][o]
#          [y][g][w]
#          [o][w][b]
#          [w][w][o]
#
# [[-0.05684625 -0.63741408  1.73176221  0.13187665  0.13682963  0.66563398]]
#          [g][r][w]
#          [g][y][o]
#          [r][w][r]
# [r][o][b][w][o][w][g][y][o][g][b][y]
# [y][r][r][g][g][b][w][o][w][r][b][r]
# [b][b][b][o][y][o][g][y][y][r][g][o]
#          [y][g][y]
#          [o][w][b]
#          [w][w][b]
#
# [[-0.35900211 -0.62547392  0.72765848  1.07225286 -0.94033843 -1.41915681]]
#          [g][r][w]
#          [g][y][o]
#          [b][r][b]
# [r][o][y][o][g][w][r][y][o][g][b][y]
# [y][r][g][y][g][o][w][o][w][r][b][r]
# [b][b][y][o][b][w][r][y][y][r][g][o]
#          [g][w][g]
#          [o][w][b]
#          [w][w][b]
#
# [[ 0.4882865  -0.28922276  0.10530165  0.95898667  0.24887959  1.06072263]]
#          [o][r][w]
#          [r][y][o]
#          [y][r][b]
# [b][y][r][g][g][w][r][y][o][g][b][w]
# [b][r][o][g][g][o][w][o][w][r][b][o]
# [y][g][y][b][b][w][r][y][y][r][g][g]
#          [o][w][g]
#          [y][w][b]
#          [o][w][b]
#
# [[ 1.03469449  1.31597636  0.12667946  1.5463423  -0.95420536 -0.64410168]]
#          [o][r][w]
#          [r][y][o]
#          [y][o][r]
# [b][y][o][b][g][g][y][y][o][g][b][w]
# [b][r][w][b][g][g][r][o][w][r][b][o]
# [y][g][g][w][o][w][b][y][y][r][g][g]
#          [r][w][r]
#          [y][w][b]
#          [o][w][b]
#
# [[ 0.32142441 -0.18136858  0.72218584  1.04102481 -0.5281274  -1.07599123]]
#          [o][r][w]
#          [r][y][o]
#          [g][w][o]
# [b][y][r][w][b][b][y][y][o][g][b][w]
# [b][r][w][o][g][g][o][o][w][r][b][o]
# [y][g][r][w][g][g][r][y][y][r][g][g]
#          [b][r][y]
#          [y][w][b]
#          [o][w][b]
#
# [[ 0.19652009 -1.63890052 -0.12431936 -0.45202496 -1.64110533 -0.38857034]]
#          [o][w][y]
#          [r][y][o]
#          [g][w][o]
# [w][y][r][w][b][b][y][y][b][r][r][g]
# [r][r][w][o][g][g][o][o][w][g][b][b]
# [o][g][r][w][g][g][r][y][o][g][o][w]
#          [b][r][y]
#          [y][w][b]
#          [b][b][y]
#
# [[-0.86460434  1.7803077  -0.15630784  0.74874687  0.97105603 -0.48847141]]
#          [g][r][o]
#          [w][y][w]
#          [o][o][y]
# [w][b][b][y][y][b][r][r][g][w][y][r]
# [r][r][w][o][g][g][o][o][w][g][b][b]
# [o][g][r][w][g][g][r][y][o][g][o][w]
#          [b][r][y]
#          [y][w][b]
#          [b][b][y]
#
# [[-0.53208571  1.79084802 -0.01141507  1.70130863 -0.40156509 -1.38452528]]
#          [o][w][g]
#          [o][y][r]
#          [y][w][o]
# [y][y][b][r][r][g][w][y][r][w][b][b]
# [r][r][w][o][g][g][o][o][w][g][b][b]
# [o][g][r][w][g][g][r][y][o][g][o][w]
#          [b][r][y]
#          [y][w][b]
#          [b][b][y]
#
# [[ 0.36932569 -1.00338079 -0.33002422  0.54771272  0.23716305  1.42088377]]
#          [w][w][g]
#          [b][y][r]
#          [b][w][o]
# [o][r][y][o][r][g][w][y][r][w][b][b]
# [g][r][y][o][g][g][o][o][w][g][b][y]
# [r][w][b][y][g][g][r][y][o][g][o][b]
#          [r][r][y]
#          [o][w][b]
#          [w][b][y]
#
# [[0.77928209 2.32359947 0.54792902 1.8617184  1.78664693 1.52430819]]
#          [b][b][w]
#          [w][y][w]
#          [o][r][g]
# [o][r][g][w][y][r][w][b][b][o][r][y]
# [g][r][y][o][g][g][o][o][w][g][b][y]
# [r][w][b][y][g][g][r][y][o][g][o][b]
#          [r][r][y]
#          [o][w][b]
#          [w][b][y]
#
# [[ 1.20915216 -0.81224228  0.73803097  1.1095331  -1.14304053 -1.62201598]]
#          [b][w][o]
#          [w][y][w]
#          [o][r][g]
# [w][r][g][w][y][r][w][b][y][g][g][o]
# [b][r][y][o][g][g][o][o][b][o][b][r]
# [b][w][b][y][g][g][r][y][w][b][y][y]
#          [r][r][y]
#          [o][w][b]
#          [o][g][r]
#
# [[ 1.7374351   1.29260733  0.32363756  0.69055923  1.84331685 -0.89309387]]
#          [b][w][o]
#          [w][y][w]
#          [o][r][g]
# [w][r][g][w][y][r][w][b][y][g][g][o]
# [b][r][y][o][g][g][o][o][b][o][b][r]
# [b][y][y][b][w][b][y][g][g][r][y][w]
#          [o][o][r]
#          [g][w][r]
#          [r][b][y]
#
# [[-1.03959073 -2.07923338 -0.64641528  1.0449126   2.11567963  0.77657564]]
#          [b][w][o]
#          [w][y][w]
#          [o][r][g]
# [w][r][g][w][y][r][w][b][y][g][g][o]
# [b][r][y][o][g][g][o][o][b][o][b][r]
# [r][y][w][b][y][y][b][w][b][y][g][g]
#          [r][g][o]
#          [b][w][o]
#          [y][r][r]
#
# [[-1.09855544  1.31211964 -0.32927299 -0.571353    0.87070551  1.71890231]]
#          [g][w][o]
#          [r][y][w]
#          [o][r][g]
# [r][b][w][b][y][r][w][b][y][g][g][y]
# [y][r][r][w][g][g][o][o][b][o][b][b]
# [w][y][g][o][y][y][b][w][b][y][g][r]
#          [w][g][o]
#          [o][w][o]
#          [b][r][r]
#
# [[ 1.32777222 -0.7294352   0.8275885   0.70262301  0.62850928  0.06447335]]
#          [y][b][b]
#          [r][y][w]
#          [o][r][g]
# [o][b][w][b][y][r][w][b][r][y][o][g]
# [w][r][r][w][g][g][o][o][r][g][b][g]
# [g][y][g][o][y][y][b][w][b][r][b][y]
#          [w][g][o]
#          [o][w][o]
#          [r][y][w]
#
# [[-0.56988351  0.71533136  1.53232262 -0.60642141 -0.45464334  0.57988956]]
#          [y][b][r]
#          [r][y][g]
#          [o][r][y]
# [o][b][w][b][y][o][b][o][w][g][o][g]
# [w][r][r][w][g][o][w][o][b][w][b][g]
# [g][y][g][o][y][w][b][r][r][b][b][y]
#          [w][g][r]
#          [o][w][g]
#          [r][y][y]
#
# [[-0.3130845   0.327379   -0.41989274 -0.94985863  0.4057989  -0.69558606]]
#          [y][b][r]
#          [r][y][g]
#          [o][r][y]
# [o][b][w][b][y][o][b][o][w][g][o][g]
# [w][r][r][w][g][o][w][o][b][w][b][g]
# [b][b][y][g][y][g][o][y][w][b][r][r]
#          [r][o][w]
#          [y][w][g]
#          [y][g][r]
#
# [[-1.76963931  0.18847262 -0.23129397  1.95961474  0.86574811 -0.60181906]]
#          [y][b][r]
#          [r][y][g]
#          [y][r][w]
# [o][b][r][g][w][b][o][o][w][g][o][g]
# [w][r][o][y][g][y][r][o][b][w][b][g]
# [b][b][w][g][o][o][y][y][w][b][r][r]
#          [o][w][b]
#          [y][w][g]
#          [y][g][r]
#
# [[-0.69686993  1.21727039 -1.0892065   1.14416325 -1.18698049  1.25020747]]
#          [r][b][r]
#          [g][y][g]
#          [g][r][w]
# [b][w][o][y][w][b][o][o][w][g][o][y]
# [b][r][b][r][g][y][r][o][b][w][b][y]
# [w][o][r][y][o][o][y][y][w][b][r][o]
#          [g][w][b]
#          [y][w][g]
#          [g][g][r]
#
# [[ 1.28758711  0.15090951 -1.23035879  0.47264931  1.58524449  1.19371119]]
#          [r][b][r]
#          [g][y][g]
#          [g][r][w]
# [b][w][o][y][w][b][o][o][w][g][o][y]
# [b][r][b][r][g][y][r][o][b][w][b][y]
# [b][r][o][w][o][r][y][o][o][y][y][w]
#          [g][y][g]
#          [g][w][w]
#          [r][g][b]
#
# [[-0.90482342  0.95092452  0.30266752  0.53537956 -1.74610038 -0.8923576 ]]
#          [g][g][r]
#          [r][y][b]
#          [w][g][r]
# [y][w][b][o][o][w][g][o][y][b][w][o]
# [b][r][b][r][g][y][r][o][b][w][b][y]
# [b][r][o][w][o][r][y][o][o][y][y][w]
#          [g][y][g]
#          [g][w][w]
#          [r][g][b]
#
# [[-0.11411113  2.31107884 -0.01824591 -1.20426724 -1.26290326  0.94239245]]
#          [w][r][g]
#          [g][y][g]
#          [r][b][r]
# [o][o][w][g][o][y][b][w][o][y][w][b]
# [b][r][b][r][g][y][r][o][b][w][b][y]
# [b][r][o][w][o][r][y][o][o][y][y][w]
#          [g][y][g]
#          [g][w][w]
#          [r][g][b]
#
# [[-0.03175786 -0.812884   -0.77978256  0.94131496  0.43558847  1.1685845 ]]
#          [w][r][g]
#          [y][y][g]
#          [b][b][r]
# [b][b][o][w][o][y][b][w][o][y][w][r]
# [r][r][o][g][g][y][r][o][b][w][b][g]
# [o][b][w][r][o][r][y][o][o][y][y][g]
#          [g][y][g]
#          [r][w][w]
#          [w][g][b]
#
# [[ 0.93740601 -0.81388918 -0.56115421  0.92248919  0.61543313  0.08706032]]
#          [o][b][o]
#          [y][y][g]
#          [b][b][r]
# [g][b][o][w][o][y][b][w][b][y][w][y]
# [r][r][o][g][g][y][r][o][g][y][b][w]
# [w][b][w][r][o][r][y][o][w][g][g][r]
#          [g][y][g]
#          [r][w][w]
#          [b][r][o]
#
# [[-1.14124942 -1.10429681 -0.33238942  1.34784313  1.17324794 -1.46387467]]
#          [o][b][o]
#          [y][y][g]
#          [w][o][o]
# [g][b][g][r][g][w][b][w][b][y][w][y]
# [r][r][y][o][g][o][b][o][g][y][b][w]
# [w][b][g][r][y][y][r][o][w][g][g][r]
#          [y][r][b]
#          [r][w][w]
#          [b][r][o]
#
# [[-0.49027707 -0.6986251   1.46464303  1.20866739 -0.5564311  -0.09888773]]
#          [o][b][w]
#          [y][y][o]
#          [w][o][y]
# [g][b][g][r][g][b][r][b][b][o][w][y]
# [r][r][y][o][g][w][o][o][w][g][b][w]
# [w][b][g][r][y][o][w][g][b][o][g][r]
#          [y][r][g]
#          [r][w][y]
#          [b][r][y]
#
# [[-0.70364373  0.2303696   1.17029812  1.77533478  1.54956156  1.06924819]]
#          [o][b][w]
#          [y][y][o]
#          [g][y][g]
# [g][b][y][r][o][r][w][b][b][o][w][y]
# [r][r][r][y][g][g][o][o][w][g][b][w]
# [w][b][g][o][w][b][y][g][b][o][g][r]
#          [w][o][r]
#          [r][w][y]
#          [b][r][y]
#
# [[ 0.23077945  1.04991146  0.77837481  1.19039136  0.54610362 -2.30873275]]
#          [o][b][w]
#          [y][y][o]
#          [g][r][y]
# [g][b][w][o][y][r][g][b][b][o][w][y]
# [r][r][o][w][g][o][y][o][w][g][b][w]
# [w][b][r][b][g][r][g][g][b][o][g][r]
#          [y][o][w]
#          [r][w][y]
#          [b][r][y]
#
# [[-0.85222275  0.51820576  2.3826207   1.03296006  0.01209077 -0.1201648 ]]
#          [o][b][r]
#          [y][y][o]
#          [g][r][r]
# [g][b][w][o][y][w][g][y][g][y][w][y]
# [r][r][o][w][g][y][g][o][b][o][b][w]
# [w][b][r][b][g][y][b][w][b][w][g][r]
#          [y][o][o]
#          [r][w][g]
#          [b][r][o]
#
# [[ 1.09874122  1.03036525 -0.0268133   0.15439664 -0.02169982 -0.15894273]]
#          [g][b][b]
#          [y][y][o]
#          [g][r][r]
# [r][b][w][o][y][w][g][y][o][w][o][y]
# [b][r][o][w][g][y][g][o][r][g][b][w]
# [o][b][r][b][g][y][b][w][b][r][w][y]
#          [y][o][o]
#          [r][w][g]
#          [g][r][w]
# [[ 0.50694875  1.40599908  1.64166182  0.42150894 -1.10267153 -0.15317629]]
#          [g][b][w]
#          [y][y][y]
#          [g][r][y]
# [r][b][w][o][y][o][b][g][g][r][o][y]
# [b][r][o][w][g][g][w][o][y][o][b][w]
# [o][b][r][b][g][w][b][r][o][b][w][y]
#          [y][o][r]
#          [r][w][g]
#          [g][r][w]
#
# [[-1.03993332 -0.07625842  0.99769125  1.26759062 -1.1009469   0.76084258]]
#          [g][b][w]
#          [y][y][y]
#          [r][o][w]
# [r][b][y][b][w][o][g][g][g][r][o][y]
# [b][r][o][g][g][y][r][o][y][o][b][w]
# [o][b][r][w][g][o][y][r][o][b][w][y]
#          [b][w][b]
#          [r][w][g]
#          [g][r][w]
#
# [[-0.55530039  0.96090582  0.29954296 -1.72975487  1.45374693 -0.64929907]]
#          [g][b][w]
#          [y][y][y]
#          [r][o][w]
# [r][b][y][b][w][o][g][g][g][r][o][y]
# [b][r][o][g][g][y][r][o][y][o][b][w]
# [b][w][y][o][b][r][w][g][o][y][r][o]
#          [g][r][b]
#          [r][w][w]
#          [w][g][b]
#
# [[-1.43895356 -1.52536304  0.51720291  0.63282503  0.17641074 -1.41508699]]
#          [g][b][w]
#          [y][y][y]
#          [y][o][y]
# [r][b][g][o][g][b][r][g][g][r][o][y]
# [b][r][r][b][g][w][o][o][y][o][b][w]
# [b][w][b][r][y][o][w][g][o][y][r][o]
#          [w][r][g]
#          [r][w][w]
#          [w][g][b]
#
# [[-0.03003705  0.96730268 -1.16463274 -0.48664658  0.40585818  0.96463444]]
#          [y][y][g]
#          [o][y][b]
#          [y][y][w]
# [o][g][b][r][g][g][r][o][y][r][b][g]
# [b][r][r][b][g][w][o][o][y][o][b][w]
# [b][w][b][r][y][o][w][g][o][y][r][o]
#          [w][r][g]
#          [r][w][w]
#          [w][g][b]
#
# [[ 0.86759697 -0.64191098 -0.95773901  0.78339625 -3.10650386  1.02551638]]
#          [o][y][g]
#          [w][y][b]
#          [g][y][w]
# [b][b][o][y][g][g][r][o][y][r][b][w]
# [w][r][g][o][g][w][o][o][y][o][b][r]
# [b][r][b][y][y][o][w][g][o][y][r][w]
#          [r][r][g]
#          [b][w][w]
#          [r][g][b]
#
# [[ 0.43383949 -2.10713286  0.32262111  0.19627405 -1.17477984 -0.50676262]]
#          [y][y][o]
#          [w][y][b]
#          [g][y][w]
# [g][b][o][y][g][g][r][o][b][y][o][r]
# [y][r][g][o][g][w][o][o][g][r][b][b]
# [o][r][b][y][y][o][w][g][r][w][r][w]
#          [r][r][g]
#          [b][w][w]
#          [b][w][b]
#
# [[ 1.98456322  1.83068529  0.20136831  1.90340952 -0.79963091  0.67925897]]
#          [b][g][r]
#          [w][y][b]
#          [g][y][w]
# [o][b][o][y][g][g][r][o][b][w][r][y]
# [y][r][g][o][g][w][o][o][w][r][b][o]
# [y][r][b][y][y][o][w][g][b][w][b][r]
#          [r][r][g]
#          [b][w][w]
#          [g][y][o]
#
# [[ 0.10927984  0.08628235 -0.70535455  2.02098366  1.82479573 -0.95691562]]
#          [b][g][r]
#          [w][y][b]
#          [b][g][o]
# [o][b][r][y][o][y][g][o][b][w][r][y]
# [y][r][r][y][g][g][y][o][w][r][b][o]
# [y][r][g][o][w][g][w][g][b][w][b][r]
#          [w][o][r]
#          [b][w][w]
#          [g][y][o]
#
# [[-0.47294909 -1.1918973  -1.02138538  2.13914267 -0.19985774  0.08665877]]
#          [b][g][r]
#          [w][y][b]
#          [g][r][r]
# [o][b][w][o][y][y][b][o][b][w][r][y]
# [y][r][o][w][g][o][g][o][w][r][b][o]
# [y][r][r][g][g][y][o][g][b][w][b][r]
#          [w][y][g]
#          [b][w][w]
#          [g][y][o]
#
# [[-1.41203093  0.65762988  0.69675695 -1.49452236  1.16925133  0.56547803]]
#          [b][g][r]
#          [w][y][b]
#          [g][r][r]
# [o][b][w][o][y][y][b][o][b][w][r][y]
# [y][r][o][w][g][o][g][o][w][r][b][o]
# [w][b][r][y][r][r][g][g][y][o][g][b]
#          [g][b][w]
#          [y][w][y]
#          [o][w][g]
#
# [[ 0.45184938  0.21627441  0.86275367  0.03430471  1.73154979 -0.43076023]]
#          [b][g][r]
#          [w][y][b]
#          [g][r][r]
# [o][b][w][o][y][y][b][o][b][w][r][y]
# [y][r][o][w][g][o][g][o][w][r][b][o]
# [o][g][b][w][b][r][y][r][r][g][g][y]
#          [o][y][g]
#          [w][w][b]
#          [g][y][w]
#
# [[-0.61898436 -0.18248565 -0.21258357  2.50724633 -0.14161181  1.66976431]]
#          [b][g][r]
#          [w][y][b]
#          [b][o][w]
# [o][b][o][w][w][o][g][o][b][w][r][y]
# [y][r][y][b][g][y][r][o][w][r][b][o]
# [o][g][g][r][o][y][r][r][r][g][g][y]
#          [y][g][b]
#          [w][w][b]
#          [g][y][w]
#
# [[ 0.26018956  0.41067527  0.7661011  -0.36808274 -1.24657451  0.75763625]]
#          [b][g][o]
#          [w][y][y]
#          [b][o][y]
# [o][b][o][w][w][b][r][r][g][w][r][y]
# [y][r][y][b][g][b][r][o][o][b][b][o]
# [o][g][g][r][o][w][r][w][b][r][g][y]
#          [y][g][g]
#          [w][w][r]
#          [g][y][w]
#
# [[-2.35252868 -0.14291657 -0.32109084 -0.28756672  0.35417241  0.47327679]]
#          [y][g][o]
#          [o][y][y]
#          [y][o][y]
# [o][y][o][b][w][b][r][r][g][w][r][g]
# [g][r][b][w][g][b][r][o][o][b][b][w]
# [g][y][o][b][o][w][r][w][b][r][g][y]
#          [w][g][g]
#          [b][w][r]
#          [r][y][w]
#
# [[ 0.93906439 -1.0482671  -0.41917335  0.35346158 -0.04590994  0.99775791]]
#          [y][g][o]
#          [w][y][y]
#          [g][o][y]
# [g][g][o][y][w][b][r][r][g][w][r][r]
# [y][r][y][o][g][b][r][o][o][b][b][b]
# [o][b][o][y][o][w][r][w][b][r][g][w]
#          [b][g][g]
#          [w][w][r]
#          [b][y][w]
#
# [[-0.01174423 -0.76372585  1.40306222  1.0802101  -0.25305631 -0.98766368]]
#          [y][g][b]
#          [w][y][b]
#          [g][o][w]
# [g][g][o][y][w][g][r][r][r][y][r][r]
# [y][r][y][o][g][r][w][o][r][y][b][b]
# [o][b][o][y][o][w][b][o][g][o][g][w]
#          [b][g][r]
#          [w][w][b]
#          [b][y][w]
#
# [[ 2.27784506  0.56129434 -0.62947022  0.79088885 -2.07572049  1.04872634]]
#          [r][r][g]
#          [w][y][b]
#          [g][o][w]
# [b][g][o][y][w][g][r][r][w][o][y][y]
# [g][r][y][o][g][r][w][o][y][g][b][r]
# [y][b][o][y][o][w][b][o][b][w][b][r]
#          [b][g][r]
#          [w][w][b]
#          [g][y][o]
#
# 0
# [[ 0.0738193  -0.90857542 -0.31216231 -1.3748971  -0.15117295  0.81938415]]
#          [g][b][r]
#          [g][y][o]
#          [y][g][b]
# [w][o][g][o][w][o][w][y][b][w][r][r]
# [b][r][y][g][g][o][b][o][g][r][b][y]
# [g][o][b][o][w][w][g][w][y][r][y][y]
#          [y][b][o]
#          [w][w][r]
#          [r][r][b]
#
# [[ 0.44977176 -0.55089847  0.91431662 -0.02478775 -0.07717271  0.09664386]]
#          [g][b][o]
#          [g][y][o]
#          [y][g][w]
# [w][o][g][o][w][o][g][b][w][b][r][r]
# [b][r][y][g][g][r][w][o][y][o][b][y]
# [g][o][b][o][w][b][y][g][b][r][y][y]
#          [y][b][r]
#          [w][w][r]
#          [r][r][w]
#
# [[ 0.40336747 -0.81575789 -0.28156348 -0.63530081 -0.52924721 -0.8327659 ]]
#          [w][y][b]
#          [g][y][o]
#          [y][g][w]
# [o][o][g][o][w][o][g][b][w][r][o][b]
# [b][r][y][g][g][r][w][o][r][y][b][r]
# [g][o][b][o][w][b][y][g][r][y][y][r]
#          [y][b][r]
#          [w][w][r]
#          [w][b][g]
#
# [[-1.17111826 -0.59273002  0.42956449 -0.56483131 -0.1011307  -0.52210281]]
#          [w][y][o]
#          [g][y][r]
#          [y][g][b]
# [o][o][g][o][w][r][y][w][g][w][o][b]
# [b][r][y][g][g][r][g][o][b][o][b][r]
# [g][o][b][o][w][g][r][r][w][b][y][r]
#          [y][b][y]
#          [w][w][y]
#          [w][b][r]
#
# [[-0.58834278 -0.08779479 -0.64157371  0.22565472 -0.3721168  -0.24781513]]
#          [w][y][o]
#          [g][y][r]
#          [b][y][g]
# [o][o][y][o][g][o][y][w][g][w][o][b]
# [b][r][b][w][g][w][g][o][b][o][b][r]
# [g][o][y][g][r][r][b][r][w][b][y][r]
#          [r][g][y]
#          [w][w][y]
#          [w][b][r]
#
# [[-0.02883997 -1.02273919  0.20690215  0.06203064 -0.29401753  1.51468916]]
#          [r][y][o]
#          [r][y][r]
#          [b][y][g]
# [g][b][o][w][g][o][y][w][g][w][o][w]
# [o][r][o][g][g][w][g][o][b][o][b][w]
# [y][b][y][b][r][r][b][r][w][b][y][r]
#          [o][g][y]
#          [w][w][y]
#          [g][b][r]
#
# [[ 0.10093733  0.68067152 -1.14991003 -0.67653969  0.28690081  0.03636836]]
#          [b][r][r]
#          [y][y][y]
#          [g][r][o]
# [w][g][o][y][w][g][w][o][w][g][b][o]
# [o][r][o][g][g][w][g][o][b][o][b][w]
# [y][b][y][b][r][r][b][r][w][b][y][r]
#          [o][g][y]
#          [w][w][y]
#          [g][b][r]
#
# [[-0.99539767  0.65510332  0.56326174 -0.00406036  0.16709362 -0.82203821]]
#          [g][y][b]
#          [r][y][r]
#          [o][y][r]
# [y][w][g][w][o][w][g][b][o][w][g][o]
# [o][r][o][g][g][w][g][o][b][o][b][w]
# [y][b][y][b][r][r][b][r][w][b][y][r]
#          [o][g][y]
#          [w][w][y]
#          [g][b][r]
#
# [[-0.39322247  0.22683951  0.20507715  0.83828842 -0.9380609   0.51254039]]
#          [g][y][b]
#          [r][y][r]
#          [y][o][g]
# [y][w][o][b][g][w][o][b][o][w][g][o]
# [o][r][g][r][g][o][y][o][b][o][b][w]
# [y][b][y][r][w][w][r][r][w][b][y][r]
#          [b][g][g]
#          [w][w][y]
#          [g][b][r]
#
# [[-0.0637033   0.37750036  0.9713784   0.34490186  0.07989217 -0.12482311]]
#          [g][y][w]
#          [r][y][o]
#          [y][o][w]
# [y][w][o][b][g][g][r][y][o][g][g][o]
# [o][r][g][r][g][y][r][o][b][r][b][w]
# [y][b][y][r][w][r][w][b][o][b][y][r]
#          [b][g][b]
#          [w][w][o]
#          [g][b][w]
#
# [[-0.20866057  0.05985921  0.48490983 -0.95767892 -0.15280405 -0.34573258]]
#          [g][y][g]
#          [r][y][y]
#          [y][o][r]
# [y][w][o][b][g][b][w][r][r][w][g][o]
# [o][r][g][r][g][o][b][o][y][o][b][w]
# [y][b][y][r][w][w][o][b][o][w][y][r]
#          [b][g][b]
#          [w][w][r]
#          [g][b][g]
#
# [[-0.03210769  0.32704084  0.36169234 -0.27578149 -0.28689504 -0.26742089]]
#          [g][y][b]
#          [r][y][o]
#          [y][o][w]
# [y][w][o][b][g][b][o][b][w][r][g][o]
# [o][r][g][r][g][r][b][o][r][y][b][w]
# [y][b][y][r][w][g][o][y][r][g][y][r]
#          [b][g][w]
#          [w][w][o]
#          [g][b][w]
#
# [[-0.13704865  0.59718757  0.47742482  0.43486516 -0.03805281 -0.74730052]]
#          [y][r][g]
#          [o][y][y]
#          [w][o][b]
# [b][g][b][o][b][w][r][g][o][y][w][o]
# [o][r][g][r][g][r][b][o][r][y][b][w]
# [y][b][y][r][w][g][o][y][r][g][y][r]
#          [b][g][w]
#          [w][w][o]
#          [g][b][w]
#
# [[ 0.67131449  0.30860209 -0.06073495  0.1045872   1.57846702  0.21702624]]
#          [y][r][g]
#          [o][y][y]
#          [w][o][b]
# [b][g][b][o][b][w][r][g][o][y][w][o]
# [o][r][g][r][g][r][b][o][r][y][b][w]
# [g][y][r][y][b][y][r][w][g][o][y][r]
#          [g][w][b]
#          [b][w][g]
#          [w][o][w]
#
# [[-0.47701625 -0.22666454 -0.03573968 -0.0666581   0.38325722  0.43129685]]
#          [r][r][g]
#          [w][y][y]
#          [o][o][b]
# [g][o][b][y][b][w][r][g][o][y][w][w]
# [y][r][g][o][g][r][b][o][r][y][b][b]
# [r][g][b][w][b][y][r][w][g][o][y][g]
#          [o][w][b]
#          [r][w][g]
#          [y][o][w]
#
# [[-0.25041661 -0.88028783  0.01729868 -0.36889005 -0.08898622 -0.44348703]]
#          [r][r][w]
#          [w][y][r]
#          [o][o][y]
# [g][o][b][y][b][b][r][b][r][b][w][w]
# [y][r][g][o][g][g][w][o][g][y][b][b]
# [r][g][b][w][b][w][g][r][o][g][y][g]
#          [o][w][o]
#          [r][w][y]
#          [y][o][y]
#
# [[ 0.94564966 -0.21876598  0.38541188 -0.13993913  0.04567611 -0.37251927]]
#          [r][g][o]
#          [w][y][r]
#          [o][o][y]
# [w][o][b][y][b][b][r][b][y][g][y][b]
# [r][r][g][o][g][g][w][o][o][y][b][w]
# [r][g][b][w][b][w][g][r][y][g][b][w]
#          [o][w][o]
#          [r][w][y]
#          [g][y][r]
#
# [[ 0.07972614  0.86988289  0.75678737  0.37466335  0.13917256 -1.00948193]]
#          [o][w][r]
#          [o][y][g]
#          [y][r][o]
# [y][b][b][r][b][y][g][y][b][w][o][b]
# [r][r][g][o][g][g][w][o][o][y][b][w]
# [r][g][b][w][b][w][g][r][y][g][b][w]
#          [o][w][o]
#          [r][w][y]
#          [g][y][r]
#
# [[-0.4923544  -0.23375191  0.39894227  0.20328757 -0.41113812 -0.29805173]]
#          [o][w][y]
#          [o][y][g]
#          [y][r][w]
# [y][b][b][r][b][o][g][w][g][o][o][b]
# [r][r][g][o][g][y][r][o][y][g][b][w]
# [r][g][b][w][b][r][y][o][b][r][b][w]
#          [o][w][g]
#          [r][w][y]
#          [g][y][w]
#
# [[-0.56348903 -0.00797683  0.1196619   0.2936549  -0.04534036  0.15028701]]
#          [o][w][y]
#          [o][y][g]
#          [b][g][b]
# [y][b][o][w][o][r][y][w][g][o][o][b]
# [r][r][w][b][g][b][r][o][y][g][b][w]
# [r][g][g][r][y][o][w][o][b][r][b][w]
#          [y][r][g]
#          [r][w][y]
#          [g][y][w]
#
# [[ 0.31366711  1.11101907  0.06224064  1.06324706  1.31293344 -0.46625029]]
#          [o][w][y]
#          [o][y][g]
#          [b][g][b]
# [y][b][o][w][o][r][y][w][g][o][o][b]
# [r][r][w][b][g][b][r][o][y][g][b][w]
# [r][b][w][r][g][g][r][y][o][w][o][b]
#          [g][r][y]
#          [y][w][r]
#          [w][y][g]
#
# [[-0.31038095  0.12465891 -0.26554713  0.01875009 -0.34287794 -0.23466881]]
#          [b][o][o]
#          [g][y][w]
#          [b][g][y]
# [w][o][r][y][w][g][o][o][b][y][b][o]
# [r][r][w][b][g][b][r][o][y][g][b][w]
# [r][b][w][r][g][g][r][y][o][w][o][b]
#          [g][r][y]
#          [y][w][r]
#          [w][y][g]
#
# [[ 0.18033761 -0.81354182 -0.30329205  0.12940192 -0.28319258 -0.1937829 ]]
#          [b][y][o]
#          [g][y][w]
#          [b][g][y]
# [o][o][r][y][w][g][o][o][g][w][g][y]
# [o][r][w][b][g][b][r][o][y][o][b][b]
# [b][b][w][r][g][g][r][y][w][b][w][o]
#          [g][r][y]
#          [y][w][r]
#          [w][r][r]
#
# [[-0.03542893 -0.03548563 -0.62710486  0.28153786 -0.18069531 -0.18217185]]
#          [b][y][o]
#          [g][y][w]
#          [w][w][r]
# [o][o][g][r][b][y][b][o][g][w][g][y]
# [o][r][r][g][g][w][g][o][y][o][b][b]
# [b][b][y][g][b][g][y][y][w][b][w][o]
#          [r][r][o]
#          [y][w][r]
#          [w][r][r]
#
# [[-0.05390823  0.18373358 -1.12977186  0.9209322   0.85661421  0.55463706]]
#          [b][y][o]
#          [g][y][w]
#          [y][r][g]
# [o][o][r][g][g][r][w][o][g][w][g][y]
# [o][r][r][b][g][b][w][o][y][o][b][b]
# [b][b][o][g][w][y][r][y][w][b][w][o]
#          [y][g][b]
#          [y][w][r]
#          [w][r][r]
#
# [[ 0.53590124 -0.05698104  0.49393063  1.10770204  0.20885225 -0.24362035]]
#          [b][y][o]
#          [g][y][w]
#          [o][r][r]
# [o][o][y][g][b][g][y][o][g][w][g][y]
# [o][r][g][w][g][g][r][o][y][o][b][b]
# [b][b][b][y][b][r][g][y][w][b][w][o]
#          [r][w][w]
#          [y][w][r]
#          [w][r][r]
#
# [[-0.15434569 -0.35572564 -0.10107116  0.86071905 -0.4425323   0.02053041]]
#          [b][y][o]
#          [g][y][w]
#          [b][g][y]
# [o][o][r][y][w][g][o][o][g][w][g][y]
# [o][r][w][b][g][b][r][o][y][o][b][b]
# [b][b][w][r][g][g][r][y][w][b][w][o]
#          [g][r][y]
#          [y][w][r]
#          [w][r][r]
#
# [[ 0.0341049  -0.84369612 -0.15809701  0.29888163 -0.35376962 -0.13571492]]
#          [b][y][o]
#          [g][y][w]
#          [w][w][r]
# [o][o][g][r][b][y][b][o][g][w][g][y]
# [o][r][r][g][g][w][g][o][y][o][b][b]
# [b][b][y][g][b][g][y][y][w][b][w][o]
#          [r][r][o]
#          [y][w][r]
#          [w][r][r]
#
# [[ 0.55490052  0.7697211  -0.73235494  0.28770275 -0.24897532 -0.00639136]]
#          [w][g][b]
#          [w][y][y]
#          [r][w][o]
# [r][b][y][b][o][g][w][g][y][o][o][g]
# [o][r][r][g][g][w][g][o][y][o][b][b]
# [b][b][y][g][b][g][y][y][w][b][w][o]
#          [r][r][o]
#          [y][w][r]
#          [w][r][r]
#
# [[-0.30684489  0.44447787  0.45059795 -0.36939175  0.7089935  -0.87073642]]
#          [w][g][b]
#          [w][y][y]
#          [r][w][o]
# [r][b][y][b][o][g][w][g][y][o][o][g]
# [o][r][r][g][g][w][g][o][y][o][b][b]
# [b][w][o][b][b][y][g][b][g][y][y][w]
#          [w][y][r]
#          [r][w][r]
#          [r][r][o]
#
# [[-0.46972556  1.08646344 -0.06600228 -0.12756832  0.01173076  0.3844956 ]]
#          [r][w][w]
#          [w][y][g]
#          [o][y][b]
# [b][o][g][w][g][y][o][o][g][r][b][y]
# [o][r][r][g][g][w][g][o][y][o][b][b]
# [b][w][o][b][b][y][g][b][g][y][y][w]
#          [w][y][r]
#          [r][w][r]
#          [r][r][o]
#
# [[-0.15801     0.15461517 -0.12179936  0.02477675  0.08260161  0.56566784]]
#          [w][w][w]
#          [b][y][g]
#          [y][y][b]
# [b][o][b][r][g][y][o][o][g][r][b][r]
# [w][r][o][w][g][w][g][o][y][o][b][r]
# [o][r][g][o][b][y][g][b][g][y][y][w]
#          [w][y][r]
#          [g][w][r]
#          [b][r][o]
#
# [[ 0.59706768  0.4387064  -0.20308068  0.14067067  0.12362203 -0.13128103]]
#          [g][y][g]
#          [b][y][g]
#          [y][y][b]
# [w][o][b][r][g][y][o][o][o][y][o][r]
# [w][r][o][w][g][w][g][o][r][y][b][b]
# [w][r][g][o][b][y][g][b][b][w][r][r]
#          [w][y][r]
#          [g][w][r]
#          [b][w][o]
# [[ 0.10746428  0.60845305 -0.01047183  0.22758024  1.06744781 -0.3649404 ]]
#          [g][y][g]
#          [b][y][g]
#          [y][y][b]
# [w][o][b][r][g][y][o][o][o][y][o][r]
# [w][r][o][w][g][w][g][o][r][y][b][b]
# [w][r][r][w][r][g][o][b][y][g][b][b]
#          [b][g][w]
#          [w][w][y]
#          [o][r][r]
#
# [[-0.04209449  0.96667335  0.21773927  0.65234844  0.13249683  0.76565018]]
#          [y][b][g]
#          [y][y][y]
#          [b][g][g]
# [r][g][y][o][o][o][y][o][r][w][o][b]
# [w][r][o][w][g][w][g][o][r][y][b][b]
# [w][r][r][w][r][g][o][b][y][g][b][b]
#          [b][g][w]
#          [w][w][y]
#          [o][r][r]
#
# [[0.2232944  0.96393855 0.20820045 0.04025318 0.00978615 0.28726862]]
#          [b][y][y]
#          [g][y][b]
#          [g][y][g]
# [o][o][o][y][o][r][w][o][b][r][g][y]
# [w][r][o][w][g][w][g][o][r][y][b][b]
# [w][r][r][w][r][g][o][b][y][g][b][b]
#          [b][g][w]
#          [w][w][y]
#          [o][r][r]
#
# [[ 0.10737571 -0.39866532  1.07180532 -0.24052868 -0.37669877 -0.90211822]]
#          [b][y][r]
#          [g][y][w]
#          [g][y][g]
# [o][o][o][y][o][w][o][g][w][g][g][y]
# [w][r][o][w][g][y][b][o][o][b][b][b]
# [w][r][r][w][r][r][y][r][b][y][b][b]
#          [b][g][g]
#          [w][w][y]
#          [o][r][r]
#
# [[-0.04775793  0.12807144 -0.13817125 -0.43944137  0.42509291 -0.13782617]]
#          [b][y][r]
#          [g][y][w]
#          [g][y][g]
# [o][o][o][y][o][w][o][g][w][g][g][y]
# [w][r][o][w][g][y][b][o][o][b][b][b]
# [y][b][b][w][r][r][w][r][r][y][r][b]
#          [o][w][b]
#          [r][w][g]
#          [r][y][g]
#
# [[ 0.17735595 -0.13223003  0.33822442  0.11157063 -0.47687799  0.1863277 ]]
#          [b][y][w]
#          [g][y][y]
#          [g][y][r]
# [o][o][o][y][o][b][w][b][o][g][g][y]
# [w][r][o][w][g][g][r][o][g][w][b][b]
# [y][b][b][w][r][g][r][o][w][r][r][b]
#          [o][w][y]
#          [r][w][b]
#          [r][y][g]
#
# [[-1.1261585   0.23614058 -0.10976937  0.77555304  0.24612963 -0.76173292]]
#          [b][y][w]
#          [g][y][y]
#          [b][o][o]
# [o][o][o][w][w][y][g][b][o][g][g][y]
# [w][r][w][r][g][o][y][o][g][w][b][b]
# [y][b][y][g][g][b][r][o][w][r][r][b]
#          [r][r][w]
#          [r][w][b]
#          [r][y][g]
#
# [[-0.81342774 -0.29448835 -0.49775333 -0.43566728 -0.41547561 -0.0994401 ]]
#          [b][y][w]
#          [b][y][y]
#          [y][o][o]
# [y][w][o][b][w][y][g][b][o][g][g][r]
# [b][r][o][g][g][o][y][o][g][w][b][r]
# [y][w][o][b][g][b][r][o][w][r][r][r]
#          [w][r][w]
#          [r][w][b]
#          [g][y][g]
#
# [[ 0.1658717  -0.40238116  0.87668127 -0.73748197  0.26167355  0.67241194]]
#          [b][y][y]
#          [b][y][o]
#          [y][o][b]
# [y][w][o][b][w][w][r][y][g][o][g][r]
# [b][r][o][g][g][b][o][o][b][y][b][r]
# [y][w][o][b][g][g][w][g][o][w][r][r]
#          [w][r][r]
#          [r][w][w]
#          [g][y][g]
#
# [[ 0.00353982  0.02497974 -0.7902788  -0.07549169  0.0896384  -0.07627825]]
#          [b][y][y]
#          [b][y][o]
#          [y][o][b]
# [y][w][o][b][w][w][r][y][g][o][g][r]
# [b][r][o][g][g][b][o][o][b][y][b][r]
# [w][r][r][y][w][o][b][g][g][w][g][o]
#          [g][r][w]
#          [y][w][r]
#          [g][w][r]
#
# [[-0.04889569  0.5507401   0.06280129 -0.12601178 -0.19874324  0.09482159]]
#          [y][b][b]
#          [o][y][y]
#          [b][o][y]
# [b][w][w][r][y][g][o][g][r][y][w][o]
# [b][r][o][g][g][b][o][o][b][y][b][r]
# [w][r][r][y][w][o][b][g][g][w][g][o]
#          [g][r][w]
#          [y][w][r]
#          [g][w][r]
#
# [[ 0.24943483 -0.6446004   0.31220965 -0.2328497  -1.17538782 -0.08461345]]
#          [y][b][g]
#          [o][y][b]
#          [b][o][o]
# [b][w][w][r][y][w][b][o][o][y][w][o]
# [b][r][o][g][g][r][g][o][g][y][b][r]
# [w][r][r][y][w][r][g][b][r][b][g][o]
#          [g][r][w]
#          [y][w][y]
#          [g][w][y]
#
# [[ 0.00430047 -0.54571661 -0.54567804 -0.40412721  0.61557494 -0.29115767]]
#          [y][b][g]
#          [o][y][b]
#          [b][o][o]
# [b][w][w][r][y][w][b][o][o][y][w][o]
# [b][r][o][g][g][r][g][o][g][y][b][r]
# [b][g][o][w][r][r][y][w][r][g][b][r]
#          [g][y][g]
#          [w][w][r]
#          [y][y][w]
#
# [[ 0.65922086 -0.06806886 -0.03037215  0.67894459  0.31155691 -0.22154019]]
#          [y][b][g]
#          [o][y][b]
#          [o][o][w]
# [b][w][g][w][g][r][b][o][o][y][w][o]
# [b][r][y][r][g][y][o][o][g][y][b][r]
# [b][g][g][r][r][w][o][w][r][g][b][r]
#          [y][g][b]
#          [w][w][r]
#          [y][y][w]
#
# [[-0.00262249  0.36628236  0.25801942  0.96170826 -0.5812107  -0.53083593]]
#          [y][b][g]
#          [o][y][b]
#          [g][y][g]
# [b][w][y][r][r][w][o][o][o][y][w][o]
# [b][r][g][r][g][g][o][o][g][y][b][r]
# [b][g][b][w][y][r][w][w][r][g][b][r]
#          [o][o][b]
#          [w][w][r]
#          [y][y][w]
#
# [[-0.28706808  0.08051394 -0.74624864  0.43238307  0.15297369 -0.69265107]]
#          [y][b][g]
#          [o][y][b]
#          [b][g][y]
# [b][w][o][w][r][r][g][o][o][y][w][o]
# [b][r][o][y][g][r][y][o][g][y][b][r]
# [b][g][b][r][g][w][g][w][r][g][b][r]
#          [w][o][o]
#          [w][w][r]
#          [y][y][w]
#
# [[-0.70119764 -0.53063243 -0.68277904  0.73270244  0.27790434 -0.32717598]]
#          [y][b][g]
#          [o][y][b]
#          [b][o][o]
# [b][w][w][r][y][w][b][o][o][y][w][o]
# [b][r][o][g][g][r][g][o][g][y][b][r]
# [b][g][o][w][r][r][y][w][r][g][b][r]
#          [g][y][g]
#          [w][w][r]
#          [y][y][w]
#
# [[ 0.32268054 -1.04331392 -0.64154716  0.45856798 -0.07118275  0.67636568]]
#          [r][b][g]
#          [r][y][b]
#          [o][o][o]
# [b][b][b][y][y][w][b][o][o][y][w][y]
# [g][r][w][o][g][r][g][o][g][y][b][w]
# [o][o][w][b][r][r][y][w][r][g][b][g]
#          [r][y][g]
#          [g][w][r]
#          [w][y][w]
#
# [[-0.20242752  0.11027196  0.33703254 -0.43557411  0.94433108  0.17908671]]
#          [r][b][g]
#          [r][y][b]
#          [o][o][o]
# [b][b][b][y][y][w][b][o][o][y][w][y]
# [g][r][w][o][g][r][g][o][g][y][b][w]
# [g][b][g][o][o][w][b][r][r][y][w][r]
#          [w][g][r]
#          [y][w][y]
#          [w][r][g]
#
# [[ 0.02339696 -0.36923818 -0.5062996  -0.14840307  0.24488478  0.24223635]]
#          [r][b][g]
#          [r][y][b]
#          [o][o][o]
# [b][b][b][y][y][w][b][o][o][y][w][y]
# [g][r][w][o][g][r][g][o][g][y][b][w]
# [y][w][r][g][b][g][o][o][w][b][r][r]
#          [w][y][w]
#          [r][w][g]
#          [g][y][r]
#
# [[ 0.01596801 -0.60918649 -0.23169659 -0.12935974 -0.25254164  0.80488248]]
#          [r][b][g]
#          [w][y][b]
#          [y][o][o]
# [y][g][b][r][y][w][b][o][o][y][w][g]
# [w][r][b][r][g][r][g][o][g][y][b][r]
# [r][w][b][o][b][g][o][o][w][b][r][w]
#          [y][y][w]
#          [o][w][g]
#          [g][y][r]
#
# [[-0.82289358 -0.81122738 -0.31941976  0.45808795 -0.74327357  0.36774449]]
#          [r][b][g]
#          [w][y][b]
#          [b][b][b]
# [y][g][y][o][r][r][y][o][o][y][w][g]
# [w][r][y][b][g][y][o][o][g][y][b][r]
# [r][w][w][g][r][w][o][o][w][b][r][w]
#          [o][g][b]
#          [o][w][g]
#          [g][y][r]
#
# [[-1.3381151   0.02190256 -0.38008641 -0.65872333 -0.02017135  0.45048256]]
#          [w][b][g]
#          [r][y][b]
#          [g][b][b]
# [r][w][y][r][r][r][y][o][o][y][w][g]
# [w][r][g][w][g][y][o][o][g][y][b][o]
# [w][y][y][b][r][w][o][o][w][b][r][o]
#          [o][g][b]
#          [b][w][g]
#          [g][y][r]
#
# [[ 0.25713802  0.12672488 -0.75927628 -0.61827445  0.07823529 -0.15971587]]
#          [o][g][w]
#          [r][y][b]
#          [g][b][b]
# [g][w][y][r][r][r][y][o][r][b][y][y]
# [b][r][g][w][g][y][o][o][y][r][b][w]
# [w][y][y][b][r][w][o][o][g][o][o][g]
#          [o][g][b]
#          [b][w][g]
#          [r][w][w]
#
# [[ 0.41214139  0.53229627  0.09694649  0.72755324  0.22058924 -0.76291213]]
#          [o][g][w]
#          [r][y][b]
#          [y][g][y]
# [g][w][o][b][w][r][g][o][r][b][y][y]
# [b][r][g][r][g][r][b][o][y][r][b][w]
# [w][y][b][w][y][r][b][o][g][o][o][g]
#          [o][o][y]
#          [b][w][g]
#          [r][w][w]
#
# [[-0.79394888 -0.2018173  -0.21561733  0.05362598 -0.63900753 -0.30319968]]
#          [o][g][w]
#          [r][y][b]
#          [b][g][o]
# [g][w][o][w][r][b][y][o][r][b][y][y]
# [b][r][o][y][g][w][g][o][y][r][b][w]
# [w][y][y][r][r][r][y][o][g][o][o][g]
#          [b][b][g]
#          [b][w][g]
#          [r][w][w]
#
# [[-0.59052452 -0.54466051  0.17482204  0.64276141  0.00574848 -0.27526221]]
#          [o][g][w]
#          [r][y][b]
#          [y][o][o]
# [g][w][b][r][y][w][b][o][r][b][y][y]
# [b][r][b][r][g][r][g][o][y][r][b][w]
# [w][y][g][r][w][b][o][o][g][o][o][g]
#          [y][g][y]
#          [b][w][g]
# ...
#          [r][g][b]
#          [o][w][b]
#          [y][r][b]
#
# [[-0.00154234 -0.09684286  0.60982062 -0.14161772 -0.03909798  0.42871236]]
#          [w][b][o]
#          [b][y][w]
#          [g][w][y]
# [r][y][o][y][g][b][r][r][g][w][w][g]
# [g][r][o][y][g][b][r][o][b][o][b][o]
# [o][w][y][g][y][b][w][y][w][b][g][b]
#          [r][g][o]
#          [o][w][r]
#          [y][r][r]
#
# [[ 0.02381863 -0.12869377  0.29726232  0.2059779  -0.38855472  0.56960557]]
#          [b][b][o]
#          [o][y][w]
#          [g][w][y]
# [o][g][r][w][g][b][r][r][g][w][w][y]
# [w][r][y][b][g][b][r][o][b][o][b][o]
# [y][o][o][g][y][b][w][y][w][b][g][r]
#          [y][g][o]
#          [y][w][r]
#          [g][r][r]
#
# [[ 0.31816106  0.318682   -0.23186968  0.49698693 -0.25111864  0.14061404]]
#          [b][b][o]
#          [o][y][w]
#          [o][y][r]
# [o][g][y][g][b][w][g][r][g][w][w][y]
# [w][r][g][y][g][g][w][o][b][o][b][o]
# [y][o][o][b][b][b][y][y][w][b][g][r]
#          [w][r][r]
#          [y][w][r]
#          [g][r][r]
#
# [[-0.52620617 -0.44478882  0.03734402 -0.49026007  0.29943766 -0.18091709]]
#          [b][b][o]
#          [o][y][w]
#          [o][y][r]
# [o][g][y][g][b][w][g][r][g][w][w][y]
# [w][r][g][y][g][g][w][o][b][o][b][o]
# [b][g][r][y][o][o][b][b][b][y][y][w]
#          [g][y][w]
#          [r][w][r]
#          [r][r][r]
#
# [[ 0.13944183  0.05967164  0.7019206   0.59682076 -0.23343628 -0.14795742]]
#          [b][b][w]
#          [o][y][g]
#          [o][y][o]
# [o][g][y][g][b][w][b][w][g][r][w][y]
# [w][r][g][y][g][r][b][o][r][w][b][o]
# [b][g][r][y][o][r][b][b][g][o][y][w]
#          [g][y][y]
#          [r][w][o]
#          [r][r][w]
#
# [[ 0.2501006   0.32391995 -0.31649903 -0.09513893  0.08923097 -0.40223331]]
#          [o][o][b]
#          [y][y][b]
#          [o][g][w]
# [g][b][w][b][w][g][r][w][y][o][g][y]
# [w][r][g][y][g][r][b][o][r][w][b][o]
# [b][g][r][y][o][r][b][b][g][o][y][w]
#          [g][y][y]
#          [r][w][o]
#          [r][r][w]
#
# [[-0.07174649 -0.26581711 -0.29994958 -0.12084125 -0.02782478  0.05270602]]
#          [w][o][b]
#          [o][y][b]
#          [y][g][w]
# [b][w][g][o][w][g][r][w][y][o][g][r]
# [g][r][b][y][g][r][b][o][r][w][b][r]
# [r][g][w][o][o][r][b][b][g][o][y][g]
#          [b][y][y]
#          [y][w][o]
#          [y][r][w]
#
# [[ 0.30935688 -0.00553552  0.00196056 -0.06061507 -0.16421697  0.15464702]]
#          [y][r][g]
#          [o][y][b]
#          [y][g][w]
# [b][w][g][o][w][g][r][w][w][o][w][o]
# [o][r][b][y][g][r][b][o][r][y][b][g]
# [w][g][w][o][o][r][b][b][y][g][r][r]
#          [b][y][y]
#          [y][w][o]
#          [b][g][r]
#
# [[ 0.44755351  0.33669638  0.49653617 -0.16401704 -0.09456488 -0.40948301]]
#          [y][r][g]
#          [o][y][r]
#          [y][g][r]
# [b][w][g][o][w][y][b][b][r][w][w][o]
# [o][r][b][y][g][o][b][o][w][b][b][g]
# [w][g][w][o][o][r][y][r][w][g][r][r]
#          [b][y][g]
#          [y][w][y]
#          [b][g][o]
#
# [[ 0.1058037   0.23761663 -0.24221727  0.1041904  -0.14401607  0.71665859]]
#          [r][r][g]
#          [g][y][r]
#          [o][g][r]
# [w][o][b][y][w][y][b][b][r][w][w][b]
# [g][r][w][o][g][o][b][o][w][b][b][y]
# [w][b][g][y][o][r][y][r][w][g][r][b]
#          [o][y][g]
#          [y][w][y]
#          [o][g][o]
#
# [[ 0.57181704 -0.07955142 -0.35020334 -0.24503133  0.28561406 -1.108121  ]]
#          [r][w][w]
#          [g][y][r]
#          [o][g][r]
# [g][o][b][y][w][y][b][b][o][g][b][w]
# [r][r][w][o][g][o][b][o][g][r][b][w]
# [r][b][g][y][o][r][y][r][o][b][y][b]
#          [o][y][g]
#          [y][w][y]
#          [w][g][w]
#
# [[ 0.37907807 -0.0496241  -0.01723678 -0.15171115  0.21531035 -0.44728206]]
#          [o][g][o]
#          [g][y][r]
#          [o][g][r]
# [w][o][b][y][w][y][b][b][w][b][r][g]
# [w][r][w][o][g][o][b][o][g][y][b][b]
# [r][b][g][y][o][r][y][r][w][b][w][w]
#          [o][y][g]
#          [y][w][y]
#          [g][r][r]
#
# [[-0.65478358 -0.07061516  0.11570457  0.0371737  -0.45611998  0.19562531]]
#          [w][g][o]
#          [b][y][r]
#          [g][g][r]
# [r][w][w][o][w][y][b][b][w][b][r][g]
# [b][r][o][g][g][o][b][o][g][y][b][y]
# [g][w][b][o][o][r][y][r][w][b][w][o]
#          [y][y][g]
#          [o][w][y]
#          [y][r][r]
#
# [[-0.62194584 -0.22154871  0.21100077 -0.08946825 -0.00900485 -0.23512673]]
#          [w][g][y]
#          [b][y][o]
#          [g][g][r]
# [r][w][w][o][w][g][y][b][b][r][r][g]
# [b][r][o][g][g][y][r][o][b][r][b][y]
# [g][w][b][o][o][r][w][g][w][o][w][o]
#          [y][y][b]
#          [o][w][y]
#          [y][r][b]
#
# [[-0.13080852  0.22449276  0.21860929 -0.00457651 -0.81058849 -0.4366881 ]]
#          [g][b][w]
#          [g][y][g]
#          [r][o][y]
# [o][w][g][y][b][b][r][r][g][r][w][w]
# [b][r][o][g][g][y][r][o][b][r][b][y]
# [g][w][b][o][o][r][w][g][w][o][w][o]
#          [y][y][b]
#          [o][w][y]
#          [y][r][b]
#
# [[-0.09746395  0.31716371 -0.02809362  0.36459092  0.3318542   0.34041993]]
#          [g][b][w]
#          [g][y][g]
#          [b][o][g]
# [o][w][y][o][g][y][r][r][g][r][w][w]
# [b][r][y][o][g][b][o][o][b][r][b][y]
# [g][w][b][r][y][b][y][g][w][o][w][o]
#          [w][r][r]
#          [o][w][y]
#          [y][r][b]
#
# [[-0.52670421  0.35921712 -0.62190682 -0.04079853  0.34701617 -0.25824238]]
#          [b][g][g]
#          [o][y][b]
#          [g][g][w]
# [o][g][y][r][r][g][r][w][w][o][w][y]
# [b][r][y][o][g][b][o][o][b][r][b][y]
# [g][w][b][r][y][b][y][g][w][o][w][o]
#          [w][r][r]
#          [o][w][y]
#          [y][r][b]
#
# [[-0.18649246 -0.44904994 -0.17311354  0.3096192   0.56887767  0.8076668 ]]
#          [o][g][g]
#          [y][y][b]
#          [y][g][w]
# [g][b][o][b][r][g][r][w][w][o][w][y]
# [w][r][g][o][g][b][o][o][b][r][b][o]
# [b][y][y][g][y][b][y][g][w][o][w][w]
#          [r][r][r]
#          [o][w][y]
#          [r][r][b]
#
# [[-0.19330685 -0.31670112  0.06419581 -0.13061052 -0.07768975  0.71191707]]
#          [w][g][g]
#          [o][y][b]
#          [y][g][w]
# [b][w][g][o][r][g][r][w][w][o][w][r]
# [y][r][b][y][g][b][o][o][b][r][b][o]
# [y][g][o][y][y][b][y][g][w][o][w][r]
#          [b][r][r]
#          [o][w][y]
#          [g][r][b]
#
# [[ 0.35195873 -0.13850152 -0.29669615  0.0147504  -0.41708949  0.30208501]]
#          [w][b][w]
#          [o][y][b]
#          [y][g][w]
# [g][w][g][o][r][g][r][w][b][o][r][o]
# [g][r][b][y][g][b][o][o][r][w][b][w]
# [w][g][o][y][y][b][y][g][g][r][o][r]
#          [b][r][r]
#          [o][w][y]
#          [b][y][y]
#
# [[-0.24675984 -0.35667999  0.08278678 -0.01739813  0.20061835 -0.67155629]]
#          [w][b][w]
#          [o][y][b]
#          [y][g][w]
# [g][w][g][o][r][g][r][w][b][o][r][o]
# [g][r][b][y][g][b][o][o][r][w][b][w]
# [r][o][r][w][g][o][y][y][b][y][g][g]
#          [b][o][b]
#          [y][w][r]
#          [y][y][r]
#
# [[-0.36136414 -0.22820986  0.00086903 -0.36144389 -0.05375373  0.21229136]]
#          [g][b][w]
#          [w][y][b]
#          [o][g][w]
# [r][g][g][w][r][g][r][w][b][o][r][y]
# [o][r][w][o][g][b][o][o][r][w][b][y]
# [r][b][g][y][g][o][y][y][b][y][g][b]
#          [o][o][b]
#          [y][w][r]
#          [w][y][r]
#
# [[ 0.18041083  0.73177092 -0.47941873 -0.43345266 -0.31655595 -0.22890912]]
#          [o][w][g]
#          [g][y][b]
#          [w][b][w]
# [w][r][g][r][w][b][o][r][y][r][g][g]
# [o][r][w][o][g][b][o][o][r][w][b][y]
# [r][b][g][y][g][o][y][y][b][y][g][b]
#          [o][o][b]
#          [y][w][r]
#          [w][y][r]
#
# [[-0.28594783 -0.4753375  -0.01261203  0.28037617 -0.007708    0.06941715]]
#          [o][w][g]
#          [g][y][b]
#          [g][w][g]
# [w][r][o][y][o][r][w][r][y][r][g][g]
# [o][r][o][g][g][w][b][o][r][w][b][y]
# [r][b][b][o][b][b][w][y][b][y][g][b]
#          [y][o][o]
#          [y][w][r]
#          [w][y][r]
#
# [[ 0.42317657  0.4780455  -0.09233746 -0.34534716  0.08826769 -0.12848234]]
#          [g][g][o]
#          [w][y][w]
#          [g][b][g]
# [y][o][r][w][r][y][r][g][g][w][r][o]
# [o][r][o][g][g][w][b][o][r][w][b][y]
# [r][b][b][o][b][b][w][y][b][y][g][b]
#          [y][o][o]
#          [y][w][r]
#          [w][y][r]
#
# [[ 0.02153378 -0.56389532 -0.37382301 -0.08965928  0.0976046  -0.51552137]]
#          [g][g][o]
#          [w][y][w]
#          [g][b][g]
# [y][o][r][w][r][y][r][g][g][w][r][o]
# [o][r][o][g][g][w][b][o][r][w][b][y]
# [y][g][b][r][b][b][o][b][b][w][y][b]
#          [w][y][y]
#          [y][w][o]
#          [r][r][o]
# [[ 0.0032846   0.13652927 -0.07147545 -0.79668638  0.58990846 -0.39682866]]
#          [g][g][o]
#          [w][y][w]
#          [g][b][g]
# [y][o][r][w][r][y][r][g][g][w][r][o]
# [o][r][o][g][g][w][b][o][r][w][b][y]
# [w][y][b][y][g][b][r][b][b][o][b][b]
#          [r][y][w]
#          [r][w][y]
#          [o][o][y]
#
# [[-0.30382927  0.55985344  0.091761    0.06382595 -0.55851502 -0.31927034]]
#          [g][w][g]
#          [b][y][g]
#          [g][w][o]
# [w][r][y][r][g][g][w][r][o][y][o][r]
# [o][r][o][g][g][w][b][o][r][w][b][y]
# [w][y][b][y][g][b][r][b][b][o][b][b]
#          [r][y][w]
#          [r][w][y]
#          [o][o][y]
#
# [[-0.41843395  0.22776623 -0.0461422  -0.38983187  0.29054633 -0.32404268]]
#          [g][w][g]
#          [b][y][g]
#          [g][w][o]
# [w][r][y][r][g][g][w][r][o][y][o][r]
# [o][r][o][g][g][w][b][o][r][w][b][y]
# [o][b][b][w][y][b][y][g][b][r][b][b]
#          [o][r][r]
#          [o][w][y]
#          [y][y][w]
#
# [[-0.18601215 -0.5242249  -0.19673921  0.25223976 -0.41786667 -0.52367232]]
#          [g][w][g]
#          [b][y][g]
#          [b][o][y]
# [w][r][o][w][g][r][g][r][o][y][o][r]
# [o][r][r][y][g][g][w][o][r][w][b][y]
# [o][b][r][b][w][g][o][g][b][r][b][b]
#          [y][b][w]
#          [o][w][y]
#          [y][y][w]
#
# [[-0.68430742  0.73712544  0.19783432  0.12454982  0.27870662 -0.16702455]]
#          [b][b][g]
#          [o][y][w]
#          [y][g][g]
# [w][g][r][g][r][o][y][o][r][w][r][o]
# [o][r][r][y][g][g][w][o][r][w][b][y]
# [o][b][r][b][w][g][o][g][b][r][b][b]
#          [y][b][w]
#          [o][w][y]
#          [y][y][w]
#
# [[-0.01300295  0.32935687 -0.11713522 -0.13184402  0.0181242  -0.41067108]]
#          [y][o][b]
#          [g][y][b]
#          [g][w][g]
# [g][r][o][y][o][r][w][r][o][w][g][r]
# [o][r][r][y][g][g][w][o][r][w][b][y]
# [o][b][r][b][w][g][o][g][b][r][b][b]
#          [y][b][w]
#          [o][w][y]
#          [y][y][w]
#
# [[ 0.14350308 -0.16470986 -0.08654918  0.16325848 -0.46196932 -0.02263421]]
#          [y][o][b]
#          [g][y][b]
#          [r][r][o]
# [g][r][y][b][y][y][g][r][o][w][g][r]
# [o][r][b][w][g][o][w][o][r][w][b][y]
# [o][b][w][g][g][r][g][g][b][r][b][b]
#          [o][w][w]
#          [o][w][y]
#          [y][y][w]
#
# [[-0.80341843  0.10668194 -0.17907574  0.39139689  0.16421364  0.10992637]]
#          [y][o][b]
#          [g][y][b]
#          [w][b][y]
# [g][r][o][g][w][b][r][r][o][w][g][r]
# [o][r][w][g][g][y][r][o][r][w][b][y]
# [o][b][w][r][o][y][o][g][b][r][b][b]
#          [g][w][g]
#          [o][w][y]
#          [y][y][w]
#
# [[ 0.22919034  0.47435566 -0.16804689 -0.21885133  0.05174556  0.03799204]]
#          [w][g][y]
#          [b][y][o]
#          [y][b][b]
# [g][w][b][r][r][o][w][g][r][g][r][o]
# [o][r][w][g][g][y][r][o][r][w][b][y]
# [o][b][w][r][o][y][o][g][b][r][b][b]
#          [g][w][g]
#          [o][w][y]
#          [y][y][w]
#
# [[0.51754828 0.2060712  0.76731547 0.15087679 0.19375758 0.02273594]]
#          [w][g][o]
#          [b][y][y]
#          [y][b][y]
# [g][w][b][r][r][g][o][r][w][b][r][o]
# [o][r][w][g][g][y][g][o][g][o][b][y]
# [o][b][w][r][o][w][b][r][r][y][b][b]
#          [g][w][r]
#          [o][w][w]
#          [y][y][g]
#
# [[-0.01549533 -0.21974408  0.38068747 -0.08728672 -0.66032181  0.14467222]]
#          [w][g][g]
#          [b][y][y]
#          [y][b][w]
# [g][w][b][r][r][r][b][g][o][y][r][o]
# [o][r][w][g][g][w][r][o][r][y][b][y]
# [o][b][w][r][o][g][r][g][w][o][b][b]
#          [g][w][y]
#          [o][w][o]
#          [y][y][b]
#
# [[-0.50378847  0.35728253  0.31265109 -0.36634772  0.01965236  0.02012841]]
#          [y][b][w]
#          [b][y][g]
#          [w][y][g]
# [r][r][r][b][g][o][y][r][o][g][w][b]
# [o][r][w][g][g][w][r][o][r][y][b][y]
# [o][b][w][r][o][g][r][g][w][o][b][b]
#          [g][w][y]
#          [o][w][o]
#          [y][y][b]
#
# [[-0.06153925 -0.1679317  -0.06414941  0.39151836  0.12942264 -0.32902975]]
#          [y][b][w]
#          [b][y][g]
#          [w][w][r]
# [r][r][g][r][g][b][w][r][o][g][w][b]
# [o][r][w][o][g][g][y][o][r][y][b][y]
# [o][b][y][g][w][o][g][g][w][o][b][b]
#          [r][r][y]
#          [o][w][o]
#          [y][y][b]
#
# [[-0.1342828   0.61403402  0.65733737 -0.10495766 -0.21945764 -0.16823271]]
#          [y][b][b]
#          [b][y][g]
#          [w][w][o]
# [r][r][g][r][g][y][g][y][w][r][w][b]
# [o][r][w][o][g][o][g][o][r][g][b][y]
# [o][b][y][g][w][b][w][r][o][w][b][b]
#          [r][r][o]
#          [o][w][y]
#          [y][y][g]
#
# [[ 0.35336095 -0.16594532  0.35662049 -0.08574199 -0.10932388  0.38236396]]
#          [b][b][b]
#          [y][y][g]
#          [b][w][o]
# [o][o][r][y][g][y][g][y][w][r][w][y]
# [b][r][r][b][g][o][g][o][r][g][b][o]
# [y][w][g][w][w][b][w][r][o][w][b][r]
#          [r][r][o]
#          [o][w][y]
#          [g][y][g]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-7f05e5222489> in <module>()
#      10 for i in range(num_episodes):
#      11     #Reset environment and get first new observation
# ---> 12     s = env.reset()
#      13     print(s)
#      14     rAll = 0
#
# ~/PycharmProjects/PyCuber-RL/core/rlCuber.py in reset(self, scramble)
#      35         if scramble:
#      36             self.scramble_done = False
# ---> 37             self.scramble_state, self.scramble_arr = self.scramble()
#      38             self.scramble_ref = self.cuber
#      39             self.scramble_done = True
#
# ~/PycharmProjects/PyCuber-RL/core/rlCuber.py in scramble(self)
#      52             move = random.randint(0,self.action_spacen()-1)
#      53             scrambleArr.append(move)
# ---> 54             observation, _r, _d = self.step(move)
#      55         return observation, scrambleArr
#      56
#
# ~/PycharmProjects/PyCuber-RL/core/rlCuber.py in step(self, movement)
#      20         if self.scramble_done:
#      21             self.movementArr.append(move)
# ---> 22         cube = self.cuber.cube_move(move)
#      23         observation = self.cuber.cube_states()
#      24         reward = 1 if self.cuber.cube_solved() else 0
#
# ~/PycharmProjects/PyCuber-RL/core/utils.py in cube_move(self, movement)
#      73     def cube_move(self,movement):
#      74         self.scramble_ref = self.cube_ref(movement)
# ---> 75         return self.cube(movement)
#      76
#      77     def normal_solver(self):
#
# ~/.local/lib/python3.6/site-packages/pycuber/cube.py in __call__(self, algo)
#     380         A shortcut for Cube.perform_algo().
#     381         """
# --> 382         return self.perform_algo(algo)
#     383
#     384     def __iter__(self):
#
# ~/.local/lib/python3.6/site-packages/pycuber/cube.py in perform_algo(self, algo)
#     571         formula = Formula(algo)
#     572         for step in formula:
# --> 573             self.perform_step(step)
#     574         return self
#     575
#
# ~/.local/lib/python3.6/site-packages/pycuber/cube.py in perform_step(self, step)
#     556         step = Step(step)
#     557         if step.face in "LUFDRBMES":
# --> 558             return _single_layer(self, step)
#     559         else:
#     560             return _other_rotations(self, step)
#
# ~/.local/lib/python3.6/site-packages/pycuber/cube.py in _single_layer(self, step)
#     512                 parent=self,
#     513                 children=new.values(),
# --> 514                 **new
#     515             )
#     516             self[new_cubie.location] = new_cubie
#
# ~/.local/lib/python3.6/site-packages/pycuber/cube.py in __init__(self, parent, children, **kwargs)
#     232         if len(kwargs) != 2:
#     233             raise ValueError("An Edge has 2 Squares, got {0}.".format(len(kwargs)))
# --> 234         super(Edge, self).__init__(parent, children, **kwargs)
#     235         self.type = "edge"
#     236
#
# ~/.local/lib/python3.6/site-packages/pycuber/cube.py in __init__(self, parent, children, **kwargs)
#     105         self.facings = FrozenDict(kwargs)
#     106         self.parent = parent
# --> 107         self.children = set(children)
#     108         self.location = "".join(kwargs)
#     109
#
# ~/.local/lib/python3.6/site-packages/pycuber/cube.py in __hash__(self)
#      76             "orange": 0xFFA500,
#      77             "blue": 0x0000FF,
# ---> 78             "unknown": 0x000000
#      79         }
#      80         return hash(str(self)) + colour_to_hex[self.colour]
#
# KeyboardInterrupt:
